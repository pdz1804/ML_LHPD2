# %%
import sys
import os

# Add the src folder to the system path
sys.path.append(r"E:\2_LEARNING_BKU\2_File_2\K22_HK242\CO3117_Machine_Learning\Main\src")

from visualization import DataVisualizer

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: e:\2_LEARNING_BKU\2_File_2\K22_HK242\CO3117_Machine_Learning\Main\src\visualization

# %%
import pandas as pd

# Load processed data
processed_data_path = "../../data/processed/processed_data.csv"
data = pd.read_csv(processed_data_path)

# Initialize the DataVisualizer
visualizer = DataVisualizer(data)
print(dir(visualizer))  # Verify
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'data', 'plot_all_distributions', 'plot_all_relationships', 'plot_class_distribution', 'plot_correlation_matrix', 'plot_feature_relationship', 'plot_overview']

# %%
# Plot class distribution
visualizer.plot_class_distribution("target")

# %%
visualizer.plot_all_relationships()
# Out:
# Not enough numerical features for pairwise relationships.

# %%
visualizer.plot_correlation_matrix()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 visualizer.plot_correlation_matrix()
#
# File E:\2_LEARNING_BKU\2_File_2\K22_HK242\CO3117_Machine_Learning\Main\src\visualization\visualize.py:94, in DataVisualizer.plot_correlation_matrix(self)
#      90 def plot_correlation_matrix(self):
#      91     """
#      92     Plot the correlation matrix for numerical features in the dataset.
#      93     """
# ---> 94     corr = self.data.corr()
#      95     if corr.empty:
#      96         print("No numerical features to compute correlation.")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: "is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!"
