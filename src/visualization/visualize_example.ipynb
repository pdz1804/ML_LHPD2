# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter
import re
import os
import spacy
import sys
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 1.7 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.3/12.8 MB 1.9 MB/s eta 0:00:07
#      ----- ---------------------------------- 1.8/12.8 MB 1.9 MB/s eta 0:00:06
#      ------ --------------------------------- 2.1/12.8 MB 1.8 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.9 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.4/12.8 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.9/12.8 MB 2.2 MB/s eta 0:00:05
# ...

# %%
from visualize import DataVisualizer
sys.path.append(r"C:\Users\nguyenloc\OneDrive\Desktop\ML242\ML_LHPD2\src\visualization")
print("Current Working Directory:", os.getcwd())

# Load data
processed_data_path = r"C:\Users\nguyenloc\OneDrive\Desktop\ML242\ML_LHPD2\data\final\final_clean_no_neutral_no_duplicates_v1.csv"

if os.path.exists(processed_data_path):
    data = pd.read_csv(processed_data_path)
    print("Data loaded successfully!")
else:
    print(f"File does not exist at: {processed_data_path}")
    print("Please check the file path or file name!")
    exit()

sample_size = int(0.01 * len(data))  # 1% of the dataset
data_sample = data.sample(n=sample_size, random_state=42)  
print(f"Sampled {sample_size} rows (1% of the dataset) to reduce processing time.")

data_sample['target'] = pd.to_numeric(data_sample['target'], errors='coerce')
data_sample = data_sample.dropna(subset=['target'])
visualizer = DataVisualizer(data_sample)

# data['target'] = pd.to_numeric(data['target'], errors='coerce')
# data = data.dropna(subset=['target'])
# visualizer = DataVisualizer(data)

print(dir(visualizer))


# sys.path.append(r"C:\Users\nguyenloc\OneDrive\Desktop\ML242\ML_LHPD2\src\visualization")
# print("Current Working Directory:", os.getcwd())

# # Load data
# processed_data_path = r"C:\Users\nguyenloc\OneDrive\Desktop\ML242\ML_LHPD2\data\final\final_clean_no_neutral_no_duplicates_v1.csv"

# if os.path.exists(processed_data_path):
#     data = pd.read_csv(processed_data_path)
#     print("Data loaded successfully!")
# else:
#     print(f"File does not exist at: {processed_data_path}")
#     print("Please check the file path or file name!")
#     exit()

# # Convert target column to numeric and drop NaN values
# data['target'] = pd.to_numeric(data['target'], errors='coerce')
# data = data.dropna(subset=['target'])

# # Initialize DataVisualizer with full dataset
# visualizer = DataVisualizer(data)

# print(dir(visualizer))
# Out:
# Current Working Directory: c:\Users\nguyenloc\OneDrive\Desktop\ML242\ML_LHPD2\src\visualization
# Dữ liệu đã được load thành công!
# Đã lấy mẫu 16523 dòng (1% dataset) để giảm thời gian xử lý.
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'data', 'plot_all_distributions', 'plot_all_relationships', 'plot_class_distribution', 'plot_class_distribution_nega_posi', 'plot_feature_relationship', 'plot_length_sentiment_scatter', 'plot_negative_words_and_wordcloud', 'plot_overview', 'plot_positive_words_and_wordcloud', 'plot_text_length_distribution', 'plot_top_words_and_wordcloud', 'plot_word_frequency_by_sentiment']

# %%
visualizer.plot_class_distribution("target")
visualizer.plot_all_relationships()

# numeric_cols = data_sample.select_dtypes(include=["number"]).columns
# if len(numeric_cols) >= 2:
#     for i in range(len(numeric_cols)):
#         for j in range(i + 1, len(numeric_cols)):
#             try:
#                 visualizer.plot_feature_relationship(numeric_cols[i], numeric_cols[j])
#             except Exception as e:
#                 print(f"Lỗi khi vẽ mối quan hệ giữa {numeric_cols[i]} và {numeric_cols[j]}: {e}")
# else:
#     print("Không đủ cột số để vẽ biểu đồ quan hệ trong dữ liệu mẫu.")

# %%
visualizer.plot_top_words_and_wordcloud(text_column='text_clean')
visualizer.plot_positive_words_and_wordcloud(text_column='text_clean')
visualizer.plot_negative_words_and_wordcloud(text_column='text_clean')

# %%
visualizer.plot_text_length_distribution()

# %%
visualizer.plot_word_frequency_by_sentiment()
# Out:
# Unique values in target: [4. 0.]

# %%
visualizer.plot_length_sentiment_scatter()
